# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")

# %%
df = pd.read_csv("/content/telco_churn.csv.csv")
df.head(30)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
df.value_counts()
# Out:
# customerID  gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines     InternetService  OnlineSecurity       OnlineBackup         DeviceProtection     TechSupport          StreamingTV          StreamingMovies      Contract        PaperlessBilling  PaymentMethod              MonthlyCharges  TotalCharges  Churn
# 9995-HOTOH  Male    0              Yes      Yes         63      No            No phone service  DSL              Yes                  Yes                  Yes                  No                   Yes                  Yes                  Two year        No                Electronic check           59.00           3707.6        No       1
# ...

# %%
df.value_counts(normalize=True)
# Out:
# customerID  gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines     InternetService  OnlineSecurity       OnlineBackup         DeviceProtection     TechSupport          StreamingTV          StreamingMovies      Contract        PaperlessBilling  PaymentMethod              MonthlyCharges  TotalCharges  Churn
# 9995-HOTOH  Male    0              Yes      Yes         63      No            No phone service  DSL              Yes                  Yes                  Yes                  No                   Yes                  Yes                  Two year        No                Electronic check           59.00           3707.6        No       0.000142
# ...

# %% [markdown]
# *   Dataset contains both numerical and categorical features.
# *   churn is imbalanced
# *   Tenure and contract type may strongly influence churn

# %%
sns.countplot(x="Contract", hue="Churn", data=df)
plt.xticks(rotation=15)
plt.title("Churn Count by Contract Type")
plt.show()

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["TotalCharges"]
pd.to_numeric(df["TotalCharges"], errors="coerce")
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop("customerID", axis=1)

# %%
df["Churn"] = df["Churn"].map({"Yes": 1 , "No": 0})

# %%
df_encoded = pd.get_dummies(df , drop_first=True)

# %%
from sklearn.model_selection import train_test_split
x = df_encoded.drop("Churn" , axis=1)
y = df_encoded["Churn"]

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=42,
                                                       stratify=y)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      1035
#            1       0.63      0.54      0.58       374
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.71      0.72      1409
# weighted avg       0.79      0.79      0.79      1409

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[918, 117],
#        [173, 201]])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.794180269694819

# %% [markdown]
# *   The model identifies churners with reasonable recall
# *   False positives are acceptable if retention actions are low-cost
# *   Model performance can be improved with feature selection and tuning

# %%
importance = pd.Series(
    model.coef_[0],
    index=x_train.columns
).sort_values(key=abs , ascending=False)
importance.head(10)
# Out:
# Contract_Two year                -1.912651
# InternetService_Fiber optic       0.985038
# Contract_One year                -0.861205
# PaymentMethod_Electronic check    0.636112
# PhoneService_Yes                 -0.497141
# PaperlessBilling_Yes              0.327978
# MultipleLines_Yes                 0.316096
# TotalCharges_20.15                0.300599
# TotalCharges_19.9                 0.299346
# Dependents_Yes                   -0.259699
# dtype: float64

# %%
y.value_counts(normalize=True)
# Out:
# Churn
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %%
model_balanced = LogisticRegression(
    max_iter=1000,
    class_weight="balanced"
)

model_balanced.fit(x_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
y_pred_bal = model_balanced.predict(x_test)
y_pred_bal = model_balanced.predict_proba(x_test)[:,1]

# %%
from sklearn.metrics import classification_report, roc_auc_score
print(classification_report(y_test, y_pred_bal_binary))
roc_auc_score(y_test, y_pred_bal)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1035
#            1       0.53      0.76      0.62       374
#
#     accuracy                           0.75      1409
#    macro avg       0.71      0.76      0.72      1409
# weighted avg       0.80      0.75      0.77      1409
# np.float64(0.8400862848433182)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight="balanced"
)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
y_pred_rf = rf_model.predict(x_test)
y_pred_rf = rf_model.predict_proba(x_test)[:,1]

# %%
y_pred_rf_binary = (y_pred_rf > 0.5).astype(int)
print(classification_report(y_test, y_pred_rf_binary))
roc_auc_score(y_test, y_pred_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87      1035
#            1       0.65      0.50      0.56       374
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.70      0.72      1409
# weighted avg       0.78      0.80      0.79      1409
# np.float64(0.8287000439174352)

# %%
importances = pd.Series(
    rf_model.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)
importances.head(10)
# Out:
# tenure                            0.121007
# MonthlyCharges                    0.091915
# Contract_Two year                 0.042327
# PaymentMethod_Electronic check    0.028582
# InternetService_Fiber optic       0.026902
# OnlineSecurity_Yes                0.024842
# Contract_One year                 0.024794
# TechSupport_Yes                   0.022741
# PaperlessBilling_Yes              0.021615
# gender_Male                       0.018108
# dtype: float64

# %% [markdown]
# * Contract type and tenure are the strongest predictors
# * Monthly charges significantly influence churn
# * Long-term contracts reduce churn probability

# %%
import joblib
joblib.dump(rf_model, "Churn_model.pkl")
# Out:
# ['Churn_model.pkl']

# %%
df_encoded.to_csv("processed_Churn_data.csv", index=False)

# %%
from google.colab import files
files.download("Customer_churn_prediction.ipynb")
files.download("Churn_model.pkl")
files.download("processed_Churn_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3283065930.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download("Customer_churn_prediction.ipynb")
#       3 files.download("Churn_model.pkl")
#       4 files.download("processed_Churn_data.csv")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: Customer_churn_prediction.ipynb

# %%
# !ls
# Out:
# Churn_model.pkl  processed_Churn_data.csv  sample_data	telco_churn.csv.csv
